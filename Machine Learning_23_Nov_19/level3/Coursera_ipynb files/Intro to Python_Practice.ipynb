# %%
people = ['Dr. Christopher Brooks', 'Dr. Kevyn Collins-Thompson', 'Dr. VG Vinod Vydiswaran', 'Dr. Daniel Romero']

def split_title_and_name(person):
    for i in people:
        print(i.split()[0],i.split()[-1])
    
split_title_and_name(people)
# Out:
# Dr. Brooks
# Dr. Collins-Thompson
# Dr. Vydiswaran
# Dr. Romero

# %%
people = ['Dr. Christopher Brooks', 'Dr. Kevyn Collins-Thompson', 'Dr. VG Vinod Vydiswaran', 'Dr. Daniel Romero']

def split_title_and_name(person):
    title = person.split()[0]
    lastname = person.split()[-1]
    return '{} {}'.format(title, lastname)

list(map(split_title_and_name, people))
# Out:
# ['Dr. Brooks', 'Dr. Collins-Thompson', 'Dr. Vydiswaran', 'Dr. Romero']

# %%
people = ['Dr. Christopher Brooks', 'Dr. Kevyn Collins-Thompson', 'Dr. VG Vinod Vydiswaran', 'Dr. Daniel Romero']

def split_title_and_name(person):
    return person.split()[0] + ' ' + person.split()[-1]

#option 1
for person in people:
    print(person)
    print(split_title_and_name(person) == (lambda person:person.split()[0] + ' ' + person.split()[-1])(person))

#option 2
list(map(split_title_and_name, people)) == list(map(lambda person:person.split()[0] + ' ' + person.split()[-1],people))
# Out:
# Dr. Christopher Brooks
# True
# Dr. Kevyn Collins-Thompson
# True
# Dr. VG Vinod Vydiswaran
# True
# Dr. Daniel Romero
# True
# True

# %%
people = ['Dr. Christopher Brooks', 'Dr. Kevyn Collins-Thompson', 'Dr. VG Vinod Vydiswaran', 'Dr. Daniel Romero']

def split_title_and_name(person):
    return person.split()[0] + ' ' + person.split()[-1]

#option 1
for person in people:
    print(split_title_and_name(person) == (lambda x: x.split()[0] + ' ' + x.split()[-1])(person))

#option 2
list(map(split_title_and_name, people)) == list(map(lambda person: person.split()[0] + ' ' + person.split()[-1], people))
# Out:
# True
# True
# True
# True
# True

# %%
def times_tables():
    lst = []
    for i in range(10):
        for j in range (10):
            lst.append(i*j)
    return lst

times_tables() == [j*i for i in range(10) for j in range(10)]
# Out:
# True

# %%
def times_tables():
    lst = []
    for i in range(10):
        for j in range (10):
            lst.append(i*j)
    return lst

times_tables() == [j*i for i in range(10) for j in range(10)]
# Out:
# True

# %%
lowercase = 'abcdefghijklmnopqrstuvwxyz'
digits = '0123456789'

answer = []
#correct_answer == answer

# %%
lowercase = 'abcdefghijklmnopqrstuvwxyz'
digits = '0123456789'

correct_answer = [a+b+c+d for a in lowercase for b in lowercase for c in digits for d in digits]

correct_answer[:] # Display first 50 ids
# Out:
# ['aa00',
#  'aa01',
#  'aa02',
#  'aa03',
#  'aa04',
#  'aa05',
#  'aa06',
#  'aa07',
#  'aa08',
#  'aa09',
#  'aa10',
#  'aa11',
#  'aa12',
#  'aa13',
#  'aa14',
#  'aa15',
#  'aa16',
#  'aa17',
#  'aa18',
#  'aa19',
#  'aa20',
#  'aa21',
#  'aa22',
#  'aa23',
#  'aa24',
#  'aa25',
#  'aa26',
#  'aa27',
#  'aa28',
#  'aa29',
#  'aa30',
#  'aa31',
#  'aa32',
#  'aa33',
#  'aa34',
#  'aa35',
#  'aa36',
#  'aa37',
#  'aa38',
#  'aa39',
#  'aa40',
#  'aa41',
#  'aa42',
#  'aa43',
#  'aa44',
#  'aa45',
#  'aa46',
#  'aa47',
#  'aa48',
#  'aa49',
#  'aa50',
#  'aa51',
#  'aa52',
#  'aa53',
#  'aa54',
#  'aa55',
#  'aa56',
#  'aa57',
#  'aa58',
#  'aa59',
#  'aa60',
#  'aa61',
#  'aa62',
#  'aa63',
#  'aa64',
#  'aa65',
#  'aa66',
#  'aa67',
#  'aa68',
#  'aa69',
#  'aa70',
#  'aa71',
#  'aa72',
#  'aa73',
#  'aa74',
#  'aa75',
#  'aa76',
#  'aa77',
#  'aa78',
#  'aa79',
#  'aa80',
#  'aa81',
#  'aa82',
#  'aa83',
#  'aa84',
#  'aa85',
#  'aa86',
#  'aa87',
#  'aa88',
#  'aa89',
# ...

# %%
import numpy as np
old = np.array([[1, 1, 1],
                [1, 1, 1]])

new = old
new[0, :2] = 0

print(old)
# Out:
# [[0 0 1]
#  [1 1 1]]

# %%
old = np.array([[1, 1, 1],
                [1, 1, 1]])

new = old.copy()
new[:, 0] = 0

print(old)
# Out:
# [[1 1 1]
#  [1 1 1]]

# %% [markdown]
# # https://planetpython.org/

# %% [markdown]
# * For the purchase records from the pet store, how would you get a list of all items which had been purchased (regardless of where they might have been purchased, or by whom)?

# %%
import pandas as pd
purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})

df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 0', 'Store 1', 'Store 2'])

# Your code here
df
# Out:
#           Name Item Purchased  Cost
# Store 0  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
df["Item Purchased"]
# Out:
# Store 0        Dog Food
# Store 1    Kitty Litter
# Store 2       Bird Seed
# Name: Item Purchased, dtype: object

# %% [markdown]
# * For the purchase records from the pet store, how would you update the DataFrame, applying a discount of 20% across all the values in the 'Cost' column?

# %%
purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})

df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 1', 'Store 1', 'Store 2'])

# Your answer here
copy_df = df.copy()
copy_df = copy_df.drop("Cost",axis=1)
cost=df["Cost"]/100
copy_df["Cost"]=cost
df=copy_df
print(df)
# Out:
#           Name Item Purchased   Cost
# Store 1  Chris       Dog Food  0.225
# Store 1  Kevyn   Kitty Litter  0.025
# Store 2  Vinod      Bird Seed  0.050

# %%
copy_df = df.copy()
copy_df = copy_df.drop("Cost",axis=1)
copy_df
# Out:
#           Name Item Purchased
# Store 1  Chris       Dog Food
# Store 1  Kevyn   Kitty Litter
# Store 2  Vinod      Bird Seed

# %%
df
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
cost=df["Cost"]/100
copy_df["Cost"]=cost
copy_df
# Out:
#           Name Item Purchased   Cost
# Store 1  Chris       Dog Food  0.225
# Store 1  Kevyn   Kitty Litter  0.025
# Store 2  Vinod      Bird Seed  0.050

# %%
df=copy_df
df
# Out:
#           Name Item Purchased   Cost
# Store 1  Chris       Dog Food  0.225
# Store 1  Kevyn   Kitty Litter  0.025
# Store 2  Vinod      Bird Seed  0.050

# %%
purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})

df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 1', 'Store 1', 'Store 2'])


df['Cost'] *= 0.8
print(df)
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  18.0
# Store 1  Kevyn   Kitty Litter   2.0
# Store 2  Vinod      Bird Seed   4.0

# %%
import pandas as pd
import numpy as np
import re
data_file=pd.read_excel("Energy+Indicators.xls",skiprows=15,skipfooter=38,usecols=[2,3,4,5])# read excel file,del 15rows,38rows from tail,extract wanted columns
data_file.columns=data_file.iloc[0] # set row as column name
#data_file=data_file['Country'].str.replace(r"\(.*\)","")
data_file=data_file.drop([0,1]) # del rows 
# #data_file.set_index(data_file.columns[0]) # set column as index 
data_file=data_file.set_index(data_file.columns[0]).replace("...",np.NaN) # replace ... into NaN
data_file["Energy Supply"]=data_file["Energy Supply"]*1000000  # multiplex 1000000 to energy supply
data_file=data_file.rename({"Republic of Korea": "South Korea",
"United States of America": "United States",
"United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
"China, Hong Kong Special Administrative Region": "Hong Kong"})

#data_file.columns[0]=data_file.rename(columns= {})
data_file.columns
# Out:
# Index(['Energy Supply', 'Energy Supply per capita',
#        'Renewable Electricity Production'],
#       dtype='object', name=0)

# %%
import pandas as pd
dfile=pd.read_csv("world_bank.csv",skiprows=4)
dfile= dfile.rename(columns = {"Country Name":"Country"})
dfile["Country"]=dfile["Country"].replace({"Korea, Rep.": "South Korea", 
"Iran, Islamic Rep.": "Iran",
"Hong Kong SAR, China": "Hong Kong"})
gdp=dfile[["Country","2006","2007",'2008','2009', '2010', '2011', '2012', '2013', '2014', '2015']]
gdp=gdp.set_index("Country")
gdp
# Out:
#                                                            2006          2007  \
# Country
# Aruba                                                       NaN           NaN
# Andorra                                            4.018196e+09  4.021331e+09
# Afghanistan                                        1.030523e+10  1.172119e+10
# Angola                                             5.581103e+10  6.842044e+10
# Albania                                            9.771760e+09  1.034829e+10
# Arab World                                         1.763820e+12  1.863480e+12
# United Arab Emirates                               2.789490e+11  2.878320e+11
# Argentina                                          3.788140e+11  4.089890e+11
# Armenia                                            8.679746e+09  9.873142e+09
# American Samoa                                              NaN           NaN
# Antigua and Barbuda                                1.268714e+09  1.389229e+09
# ...

# %%
gdp
# Out:
#                                                            2006          2007  \
# Country
# Aruba                                                       NaN           NaN
# Andorra                                            4.018196e+09  4.021331e+09
# Afghanistan                                        1.030523e+10  1.172119e+10
# Angola                                             5.581103e+10  6.842044e+10
# Albania                                            9.771760e+09  1.034829e+10
# Arab World                                         1.763820e+12  1.863480e+12
# United Arab Emirates                               2.789490e+11  2.878320e+11
# Argentina                                          3.788140e+11  4.089890e+11
# Armenia                                            8.679746e+09  9.873142e+09
# American Samoa                                              NaN           NaN
# Antigua and Barbuda                                1.268714e+09  1.389229e+09
# ...

# %%
import pandas as pd
import numpy as np

data_file=pd.read_excel("Energy+Indicators.xls",skiprows=17,skipfooter=38,usecols=[2,3,4,5])# read excel file,del 15rows,38rows from tail,extract wanted columns
data_file.columns=['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
data_file=data_file.replace("...",np.NaN) # replace ... into NaN
data_file["Energy Supply"]=data_file["Energy Supply"]*1000000  # multiplex 1000000 to energy supply
data=data_file['Country'].str.replace(r" \(.*\)","")
data_file["Country"]=data.str.split(r"\d{1,3}").str.get(0)
data_file["Country"]=data_file["Country"].replace({"Republic of Korea": "South Korea","United States of America": "United States","United Kingdom of Great Britain and Northern Ireland": "United Kingdom","China, Hong Kong Special Administrative Region": "Hong Kong"})
data_file=data_file.set_index("Country")
data_file
# Out:
#                                            Energy Supply  \
# Country
# Afghanistan                                 3.210000e+08
# Albania                                     1.020000e+08
# Algeria                                     1.959000e+09
# American Samoa                                       NaN
# Andorra                                     9.000000e+06
# Angola                                      6.420000e+08
# Anguilla                                    2.000000e+06
# Antigua and Barbuda                         8.000000e+06
# Argentina                                   3.378000e+09
# Armenia                                     1.430000e+08
# Aruba                                       1.200000e+07
# Australia                                   5.386000e+09
# Austria                                     1.391000e+09
# Azerbaijan                                  5.670000e+08
# Bahamas                                     4.500000e+07
# ...

# %%
data=data_file['Country'].str.replace(r" \(.*\)","")
data.str.split(r"\d{1,3}").str.get(0)

# %%
d=pd.read_excel("scimagojr-3.xlsx")
d=d[0:15]
d=d.set_index("Country")
d
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
res=pd.merge(d,data_file,how="inner",right_on="Country",left_on="Country")
result=pd.merge(res,gdp,how="inner",right_on="Country",left_on="Country")
result
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
result[ ['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy Supply', 'Energy Supply per Capita', '% Renewable', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']]
# Out:
#     Rank  Documents  Citable documents  Citations  Self-citations  \
# 0      1     127050             126767     597237          411683
# 1      3      30504              30287     223024           61554
# 2      5      18534              18301      34266           12422
# 3      6      17899              17620     215003           40930
# 4      7      17027              16831     140566           27426
# 5      8      15005              14841     128763           37209
# 6      9      13153              12973     130632           28601
# 7     11      10964              10794     111850           26661
# 8     12       9428               9330     123336           23964
# 9     13       8896               8819      57470           19125
# 10    14       8831               8725      90765           15606
# 11    15       8668               8596      60702           14396
#
#     Citations per document  H index  Energy Supply  Energy Supply per Capita  \
# ...

# %%
for do in d["Country"]:
    if do not in x["Country"]:
        print(do)
# Out:
# China
# United States
# Japan
# United Kingdom
# Russian Federation
# Canada
# Germany
# India
# France
# South Korea
# Italy
# Spain
# Iran
# Australia
# Brazil

# %%
d
# Out:
# Index(['Rank', 'Country', 'Documents', 'Citable documents', 'Citations',
#        'Self-citations', 'Citations per document', 'H index'],
#       dtype='object')
